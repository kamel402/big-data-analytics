# %% [markdown]
# # Lab5: Frequent item mining (s437036583)

# %% [markdown]
# ### Perform Frequent item mining on the following dataset using SON algorithm
#
# https://www.kaggle.com/datasets/irfanasrullah/groceries
#
# ## Tasks
#
# 1. Preprocess the dataset.
# 1. implement the FP-Growth.
# 1. implement the PrefixSpan.
# 1. implement the SON.

# %%
import csv

# %% [markdown]
# #### Preprocess the dataset

# %%
sc = spark.sparkContext
inputFile = 'dbfs:/FileStore/shared_uploads/s437036583@st.uqu.edu.sa/groceries___groceries.csv'

dataset = sc.textFile(inputFile).mapPartitions(lambda x : csv.reader(x))
# Data PreProcessing
header = dataset.first()
# Exclude the header
dataset = dataset.filter(lambda x: x != header)
# Exclude null values
dataset = dataset.map(lambda x: [i for i in x if i])
# Exclude numbers and add index to each transaction
dataset = dataset.map(lambda x: x[1:len(x)]).zipWithIndex()
print(dataset.collect())
# Out:
# [(['citrus fruit', 'semi-finished bread', 'margarine', 'ready soups'], 0), (['tropical fruit', 'yogurt', 'coffee'], 1), (['whole milk'], 2), (['pip fruit', 'yogurt', 'cream cheese', 'meat spreads'], 3), (['other vegetables', 'whole milk', 'condensed milk', 'long life bakery product'], 4), (['whole milk', 'butter', 'yogurt', 'rice', 'abrasive cleaner'], 5), (['rolls/buns'], 6), (['other vegetables', 'UHT-milk', 'rolls/buns', 'bottled beer', 'liquor (appetizer)'], 7), (['potted plants'], 8), (['whole milk', 'cereals'], 9), (['tropical fruit', 'other vegetables', 'white bread', 'bottled water', 'chocolate'], 10), (['citrus fruit', 'tropical fruit', 'whole milk', 'butter', 'curd', 'yogurt', 'flour', 'bottled water', 'dishes'], 11), (['beef'], 12), (['frankfurter', 'rolls/buns', 'soda'], 13), (['chicken', 'tropical fruit'], 14), (['butter', 'sugar', 'fruit/vegetable juice', 'newspapers'], 15), (['fruit/vegetable juice'], 16), (['packaged fruit/vegetables'], 17), (['chocolate'], 18), (['specialty bar'], 19), (['other vegetables'], 20), (['butter milk', 'pastry'], 21), (['whole milk'], 22), (['tropical fruit', 'cream cheese', 'processed cheese', 'detergent', 'newspapers'], 23), (['tropical fruit', 'root vegetables', 'other vegetables', 'frozen dessert', 'rolls/buns', 'flour', 'sweet spreads', 'salty snack', 'waffles', 'candy', 'bathroom cleaner'], 24), (['bottled water', 'canned beer'], 25), (['yogurt'], 26), (['sausage', 'rolls/buns', 'soda', 'chocolate'], 27), (['other vegetables'], 28), (['brown bread', 'soda', 'fruit/vegetable juice', 'canned beer', 'newspapers', 'shopping bags'], 29), (['yogurt', 'beverages', 'bottled water', 'specialty bar'], 30), (['hamburger meat', 'other vegetables', 'rolls/buns', 'spices', 'bottled water', 'hygiene articles', 'napkins'], 31), (['root vegetables', 'other vegetables', 'whole milk', 'beverages', 'sugar'], 32), (['pork', 'berries', 'other vegetables', 'whole milk', 'whipped/sour cream', 'artif. sweetener', 'soda', 'abrasive cleaner'], 33), (['beef', 'grapes', 'detergent'], 34), (['pastry', 'soda'], 35), (['fruit/vegetable juice'], 36), (['canned beer'], 37), (['root vegetables', 'other vegetables', 'whole milk', 'dessert'], 38), (['citrus fruit', 'zwieback', 'newspapers'], 39), (['sausage', 'rolls/buns', 'soda', 'canned beer', 'specialty bar', 'shopping bags'], 40), (['tropical fruit', 'root vegetables', 'whole milk', 'yogurt', 'domestic eggs', 'brown bread', 'pastry', 'sugar', 'cereals', 'coffee', 'soda', 'waffles', 'candy'], 41), (['berries', 'yogurt'], 42), (['canned beer'], 43), (['butter milk', 'yogurt', 'cream cheese', 'spread cheese', 'rolls/buns', 'bottled water', 'soda', 'newspapers'], 44), (['coffee'], 45), (['pastry', 'bottled water'], 46), (['rolls/buns'], 47), (['misc. beverages'], 48), (['root vegetables', 'other vegetables', 'butter', 'curd', 'whipped/sour cream', 'UHT-milk', 'hard cheese', 'rolls/buns', 'bottled water', 'long life bakery product'], 49), (['sausage', 'rolls/buns', 'cat food', 'newspapers'], 50), (['canned beer'], 51), (['ham', 'grapes', 'other vegetables', 'whole milk'], 52), (['turkey', 'tropical fruit', 'other vegetables', 'curd', 'domestic eggs', 'brown bread', 'semi-finished bread', 'margarine', 'baking powder', 'fruit/vegetable juice'], 53), (['whole milk', 'yogurt', 'processed cheese', 'pickled vegetables', 'soda'], 54), (['whole milk', 'curd', 'yogurt', 'pastry'], 55), (['packaged fruit/vegetables', 'brown bread', 'canned beer'], 56), (['rolls/buns', 'oil', 'bottled water', 'chewing gum', 'chocolate marshmallow', 'hygiene articles', 'napkins'], 57), (['ham', 'beef', 'whipped/sour cream', 'ice cream', 'rolls/buns', 'cat food'], 58), (['rolls/buns', 'pastry', 'sugar'], 59), (['other vegetables', 'whole milk', 'frozen vegetables', 'canned fish', 'salty snack', 'seasonal products', 'detergent'], 60), (['sausage', 'pastry'], 61), (['sausage', 'beef', 'whole milk'], 62), (['frankfurter', 'tropical fruit', 'rolls/buns', 'brown bread', 'sugar'], 63), (['rolls/buns ...
#
# *** WARNING: max output size exceeded, skipping output. ***
#
# ), (['waffles'], 9489), (['sausage', 'citrus fruit', 'nuts/prunes', 'white bread', 'pastry'], 9490), (['sausage', 'whole milk'], 9491), (['soda'], 9492), (['sausage', 'citrus fruit'], 9493), (['pip fruit', 'canned beer', 'waffles'], 9494), (['citrus fruit', 'pastry'], 9495), (['brown bread'], 9496), (['soda', 'bottled beer'], 9497), (['rolls/buns', 'margarine'], 9498), (['citrus fruit', 'tropical fruit', 'pip fruit', 'onions', 'other vegetables', 'beverages', 'processed cheese'], 9499), (['butter', 'salt', 'margarine', 'sugar'], 9500), (['whole milk', 'cream cheese'], 9501), (['fruit/vegetable juice', 'bottled beer'], 9502), (['flower (seeds)'], 9503), (['chocolate'], 9504), (['frozen fruits'], 9505), (['beef'], 9506), (['root vegetables', 'ice cream'], 9507), (['whole milk', 'rolls/buns'], 9508), (['sausage', 'chicken', 'onions', 'other vegetables', 'packaged fruit/vegetables', 'butter', 'yogurt', 'beverages', 'hard cheese', 'frozen vegetables', 'domestic eggs', 'white bread', 'bottled water', 'soda', 'fruit/vegetable juice', 'bottled beer', 'canned beer', 'sparkling wine', 'waffles', 'chocolate', 'candy', 'cleaner', 'dental care'], 9509), (['whole milk', 'tidbits', 'rolls/buns', 'bottled beer', 'napkins'], 9510), (['butter', 'butter milk', 'domestic eggs'], 9511), (['citrus fruit', 'other vegetables', 'brown bread'], 9512), (['meat', 'citrus fruit', 'tropical fruit', 'berries', 'curd', 'whipped/sour cream', 'white bread', 'bottled water', 'long life bakery product', 'chocolate marshmallow', 'candy', 'dish cleaner'], 9513), (['sausage', 'hamburger meat', 'canned beer', 'dishes'], 9514), (['UHT-milk', 'frozen meals', 'brown bread', 'fruit/vegetable juice', 'shopping bags'], 9515), (['tropical fruit', 'frozen vegetables', 'rolls/buns', 'semi-finished bread', 'bottled beer', 'waffles'], 9516), (['bottled water'], 9517), (['salty snack'], 9518), (['frankfurter', 'ham', 'tropical fruit', 'pip fruit', 'other vegetables', 'frozen vegetables', 'domestic eggs', 'zwieback', 'margarine', 'soda'], 9519), (['tropical fruit', 'berries', 'yogurt', 'brown bread', 'hygiene articles'], 9520), (['tropical fruit', 'pip fruit', 'other vegetables', 'misc. beverages'], 9521), (['sausage', 'whole milk', 'dessert', 'pastry', 'soda'], 9522), (['frankfurter', 'pork', 'pip fruit', 'other vegetables', 'hard cheese', 'frozen meals', 'frozen dessert', 'pastry', 'semi-finished bread', 'sugar', 'soda', 'salty snack', 'specialty chocolate', 'specialty bar', 'candy', 'seasonal products'], 9523), (['sausage', 'tropical fruit', 'yogurt', 'canned beer', 'long life bakery product'], 9524), (['rolls/buns', 'bottled beer'], 9525), (['hamburger meat', 'tropical fruit', 'herbs', 'other vegetables', 'whole milk', 'curd', 'ice cream', 'Instant food products', 'newspapers', 'shopping bags'], 9526), (['meat'], 9527), (['hamburger meat', 'whole milk', 'cream cheese', 'pastry', 'misc. beverages', 'fruit/vegetable juice', 'white wine'], 9528), (['ham', 'rolls/buns'], 9529), (['beef', 'yogurt', 'margarine'], 9530), (['meat'], 9531), (['tropical fruit', 'rolls/buns', 'salt', 'fruit/vegetable juice', 'bottled beer', 'napkins'], 9532), (['whole milk', 'condensed milk', 'ice cream', 'coffee', 'napkins', 'kitchen towels', 'shopping bags'], 9533), (['frankfurter', 'nuts/prunes', 'frozen meals', 'rolls/buns', 'chocolate'], 9534), (['bottled water', 'soda', 'napkins'], 9535), (['citrus fruit', 'pip fruit', 'berries', 'house keeping products'], 9536), (['other vegetables', 'oil'], 9537), (['dessert', 'soda', 'cake bar', 'shopping bags'], 9538), (['oil', 'ketchup', 'coffee'], 9539), (['bottled water'], 9540), (['root vegetables', 'other vegetables', 'butter', 'chocolate'], 9541), (['chicken'], 9542), (['whole milk', 'whipped/sour cream', 'sweet spreads', 'waffles', 'chewing gum'], 9543), (['frozen vegetables'], 9544), (['tropical fruit', 'yogurt', 'rolls/buns', 'pastry', 'coffee', 'bottled water', 'newspapers'], 9545), (['root vegetables', 'whole milk', 'frozen meals', 'domestic eggs', ...

# %% [markdown]
# #### Apply FP-Growth Algorithm

# %%
from pyspark.ml.fpm import FPGrowth

fpGrowth = FPGrowth(itemsCol="_1", minSupport=0.05, minConfidence=0.2)
model = fpGrowth.fit(dataset.toDF())

# Display frequent itemsets.
model.freqItemsets.show()

# Display generated association rules.
model.associationRules.show()

# transform examines the input items against all the association rules and summarize the
# consequents as prediction
model.transform(dataset.toDF()).show()
# Out:
# +--------------------+----+
# |               items|freq|
# +--------------------+----+
# |     [shopping bags]| 969|
# |              [beef]| 516|
# |        [rolls/buns]|1809|
# |[rolls/buns, whol...| 557|
# |       [frankfurter]| 580|
# |       [canned beer]| 764|
# |            [yogurt]|1372|
# |[yogurt, whole milk]| 551|
# |            [coffee]| 571|
# |[fruit/vegetable ...| 711|
# |            [pastry]| 875|
# |       [brown bread]| 638|
# |      [bottled beer]| 792|
# |   [root vegetables]|1072|
# |            [butter]| 545|
# |        [whole milk]|2513|
# |              [pork]| 567|
# |[whipped/sour cream]| 705|
# |      [citrus fruit]| 814|
# |     [bottled water]|1087|
# +--------------------+----+
# only showing top 20 rows
#
# +------------------+------------------+-------------------+------------------+-------------------+
# |        antecedent|        consequent|         confidence|              lift|            support|
# +------------------+------------------+-------------------+------------------+-------------------+
# |[other vegetables]|      [whole milk]|0.38675775091960063|1.5136340948246207|0.07483477376715811|
# |          [yogurt]|      [whole milk]|0.40160349854227406|1.5717351405345266|0.05602440264361973|
# |      [rolls/buns]|      [whole milk]|0.30790491984521834|1.2050317893663836|0.05663446873411286|
# |      [whole milk]|      [rolls/buns]| 0.2216474333465977|1.2050317893663838|0.05663446873411286|
# |      [whole milk]|          [yogurt]| 0.2192598487863112|1.5717351405345266|0.05602440264361973|
# |      [whole milk]|[other vegetables]|0.29287703939514526| 1.513634094824621|0.07483477376715811|
# +------------------+------------------+-------------------+------------------+-------------------+
#
# +--------------------+---+--------------------+
# |                  _1| _2|          prediction|
# +--------------------+---+--------------------+
# |[citrus fruit, se...|  0|                  []|
# |[tropical fruit, ...|  1|        [whole milk]|
# |        [whole milk]|  2|[rolls/buns, yogu...|
# |[pip fruit, yogur...|  3|        [whole milk]|
# |[other vegetables...|  4|[rolls/buns, yogurt]|
# |[whole milk, butt...|  5|[rolls/buns, othe...|
# |        [rolls/buns]|  6|        [whole milk]|
# |[other vegetables...|  7|        [whole milk]|
# |     [potted plants]|  8|                  []|
# |[whole milk, cere...|  9|[rolls/buns, yogu...|
# |[tropical fruit, ...| 10|        [whole milk]|
# |[citrus fruit, tr...| 11|[rolls/buns, othe...|
# |              [beef]| 12|                  []|
# |[frankfurter, rol...| 13|        [whole milk]|
# |[chicken, tropica...| 14|                  []|
# |[butter, sugar, f...| 15|                  []|
# |[fruit/vegetable ...| 16|                  []|
# |[packaged fruit/v...| 17|                  []|
# |         [chocolate]| 18|                  []|
# |     [specialty bar]| 19|                  []|
# +--------------------+---+--------------------+
# only showing top 20 rows

# %% [markdown]
# d ##### As we can see, out of 9835 transactions, I could only obtained 6 Association Rules with minimum 5% Support and minimum 20% Confidence.
# ##### This means that there isn't enough relations between purchases, hence we cannot rely on this rules to make recommendations for users.

# %% [markdown]
# #### Apply PrefixSpan Algorithm

# %% [markdown]
# #### Preprocess the dataset

# %%
# File location and type
file_location = inputFile
file_type = "text"

# CSV options
infer_schema = "false"
first_row_is_header = "true"
delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
df = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>value</th></tr></thead><tbody><tr><td>Item(s),Item 1,Item 2,Item 3,Item 4,Item 5,Item 6,Item 7,Item 8,Item 9,Item 10,Item 11,Item 12,Item 13,Item 14,Item 15,Item 16,Item 17,Item 18,Item 19,Item 20,Item 21,Item 22,Item 23,Item 24,Item 25,Item 26,Item 27,Item 28,Item 29,Item 30,Item 31,Item 32</td></tr><tr><td>4,citrus fruit,semi-finished bread,margarine,ready soups,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>3,tropical fruit,yogurt,coffee,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>1,whole milk,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>4,pip fruit,yogurt,cream cheese,meat spreads,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>4,other vegetables,whole milk,condensed milk,long life bakery product,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>5,whole milk,butter,yogurt,rice,abrasive cleaner,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>1,rolls/buns,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>5,other vegetables,UHT-milk,rolls/buns,bottled beer,liquor (appetizer),,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>1,potted plants,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>2,whole milk,cereals,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>5,tropical fruit,other vegetables,white bread,bottled water,chocolate,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>9,citrus fruit,tropical fruit,whole milk,butter,curd,yogurt,flour,bottled water,dishes,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>1,beef,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>3,frankfurter,rolls/buns,soda,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>2,chicken,tropical fruit,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>4,butter,sugar,fruit/vegetable juice,newspapers,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>1,fruit/vegetable juice,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>1,packaged fruit/vegetables,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>1,chocolate,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>1,specialty bar,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>1,other vegetables,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>2,butter milk,pastry,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>1,whole milk,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>5,tropical fruit,cream cheese,processed cheese,detergent,newspapers,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>11,tropical fruit,root vegetables,other vegetables,frozen dessert,rolls/buns,flour,sweet spreads,salty snack,waffles,candy,bathroom cleaner,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>2,bottled water,canned beer,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>1,yogurt,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>4,sausage,rolls/buns,soda,chocolate,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>1,other vegetables,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>6,brown bread,soda,fruit/vegetable juice,canned beer,newspapers,shopping bags,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>4,yogurt,beverages,bottled water,specialty bar,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>7,hamburger meat,other vegetables,rolls/buns,spices,bottled water,hygiene articles,napkins,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>5,root vegetables,other vegetables,whole milk,beverages,sugar,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>8,pork,berries,other vegetables,whole milk,whipped/sour cream,artif. sweetener,soda,abrasive cleaner,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>3,beef,grapes,detergent,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>2,pastry,soda,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>1,fruit/vegetable juice,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>1,canned beer,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>4,root vegetables,other vegetables,whole milk,dessert,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>3,citrus fruit,zwieback,newspapers,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>6,sausage,rolls/buns,soda,canned beer,specialty bar,shopping bags,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>13 ...

# %% [markdown]
# d ##### Convert to dataframe and exclude the first row

# %%
df = df.collect()
df = df[1:len(df)]

# %%
df = spark.sparkContext.parallelize(df)
df = df.toDF()

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>value</th></tr></thead><tbody><tr><td>4,citrus fruit,semi-finished bread,margarine,ready soups,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>3,tropical fruit,yogurt,coffee,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>1,whole milk,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>4,pip fruit,yogurt,cream cheese,meat spreads,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>4,other vegetables,whole milk,condensed milk,long life bakery product,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>5,whole milk,butter,yogurt,rice,abrasive cleaner,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>1,rolls/buns,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>5,other vegetables,UHT-milk,rolls/buns,bottled beer,liquor (appetizer),,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>1,potted plants,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>2,whole milk,cereals,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>5,tropical fruit,other vegetables,white bread,bottled water,chocolate,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>9,citrus fruit,tropical fruit,whole milk,butter,curd,yogurt,flour,bottled water,dishes,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>1,beef,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>3,frankfurter,rolls/buns,soda,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>2,chicken,tropical fruit,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>4,butter,sugar,fruit/vegetable juice,newspapers,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>1,fruit/vegetable juice,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>1,packaged fruit/vegetables,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>1,chocolate,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>1,specialty bar,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>1,other vegetables,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>2,butter milk,pastry,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>1,whole milk,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>5,tropical fruit,cream cheese,processed cheese,detergent,newspapers,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>11,tropical fruit,root vegetables,other vegetables,frozen dessert,rolls/buns,flour,sweet spreads,salty snack,waffles,candy,bathroom cleaner,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>2,bottled water,canned beer,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>1,yogurt,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>4,sausage,rolls/buns,soda,chocolate,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>1,other vegetables,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>6,brown bread,soda,fruit/vegetable juice,canned beer,newspapers,shopping bags,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>4,yogurt,beverages,bottled water,specialty bar,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>7,hamburger meat,other vegetables,rolls/buns,spices,bottled water,hygiene articles,napkins,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>5,root vegetables,other vegetables,whole milk,beverages,sugar,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>8,pork,berries,other vegetables,whole milk,whipped/sour cream,artif. sweetener,soda,abrasive cleaner,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>3,beef,grapes,detergent,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>2,pastry,soda,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>1,fruit/vegetable juice,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>1,canned beer,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>4,root vegetables,other vegetables,whole milk,dessert,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>3,citrus fruit,zwieback,newspapers,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>6,sausage,rolls/buns,soda,canned beer,specialty bar,shopping bags,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>13,tropical fruit,root vegetables,whole milk,yogurt,domestic eggs,brown bread,pastry,sugar,cereals,coffee,soda,waffles,candy,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>2,berries,yogurt,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td></tr><tr><td>1,canned beer,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,</td> ...

# %% [markdown]
# d ##### Split each row into list of string

# %%
from pyspark.sql.functions import split, col
df2 = df.select(split(col("value"),",").alias("ValueArray")) \
    .drop("value")
display(df2)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ValueArray</th></tr></thead><tbody><tr><td>List(4, citrus fruit, semi-finished bread, margarine, ready soups, , , , , , , , , , , , , , , , , , , , , , , , , , , , )</td></tr><tr><td>List(3, tropical fruit, yogurt, coffee, , , , , , , , , , , , , , , , , , , , , , , , , , , , , )</td></tr><tr><td>List(1, whole milk, , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , )</td></tr><tr><td>List(4, pip fruit, yogurt, cream cheese, meat spreads, , , , , , , , , , , , , , , , , , , , , , , , , , , , )</td></tr><tr><td>List(4, other vegetables, whole milk, condensed milk, long life bakery product, , , , , , , , , , , , , , , , , , , , , , , , , , , , )</td></tr><tr><td>List(5, whole milk, butter, yogurt, rice, abrasive cleaner, , , , , , , , , , , , , , , , , , , , , , , , , , , )</td></tr><tr><td>List(1, rolls/buns, , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , )</td></tr><tr><td>List(5, other vegetables, UHT-milk, rolls/buns, bottled beer, liquor (appetizer), , , , , , , , , , , , , , , , , , , , , , , , , , , )</td></tr><tr><td>List(1, potted plants, , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , )</td></tr><tr><td>List(2, whole milk, cereals, , , , , , , , , , , , , , , , , , , , , , , , , , , , , , )</td></tr><tr><td>List(5, tropical fruit, other vegetables, white bread, bottled water, chocolate, , , , , , , , , , , , , , , , , , , , , , , , , , , )</td></tr><tr><td>List(9, citrus fruit, tropical fruit, whole milk, butter, curd, yogurt, flour, bottled water, dishes, , , , , , , , , , , , , , , , , , , , , , , )</td></tr><tr><td>List(1, beef, , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , )</td></tr><tr><td>List(3, frankfurter, rolls/buns, soda, , , , , , , , , , , , , , , , , , , , , , , , , , , , , )</td></tr><tr><td>List(2, chicken, tropical fruit, , , , , , , , , , , , , , , , , , , , , , , , , , , , , , )</td></tr><tr><td>List(4, butter, sugar, fruit/vegetable juice, newspapers, , , , , , , , , , , , , , , , , , , , , , , , , , , , )</td></tr><tr><td>List(1, fruit/vegetable juice, , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , )</td></tr><tr><td>List(1, packaged fruit/vegetables, , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , )</td></tr><tr><td>List(1, chocolate, , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , )</td></tr><tr><td>List(1, specialty bar, , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , )</td></tr><tr><td>List(1, other vegetables, , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , )</td></tr><tr><td>List(2, butter milk, pastry, , , , , , , , , , , , , , , , , , , , , , , , , , , , , , )</td></tr><tr><td>List(1, whole milk, , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , )</td></tr><tr><td>List(5, tropical fruit, cream cheese, processed cheese, detergent, newspapers, , , , , , , , , , , , , , , , , , , , , , , , , , , )</td></tr><tr><td>List(11, tropical fruit, root vegetables, other vegetables, frozen dessert, rolls/buns, flour, sweet spreads, salty snack, waffles, candy, bathroom cleaner, , , , , , , , , , , , , , , , , , , , , )</td></tr><tr><td>List(2, bottled water, canned beer, , , , , , , , , , , , , , , , , , , , , , , , , , , , , , )</td></tr><tr><td>List(1, yogurt, , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , )</td></tr><tr><td>List(4, sausage, rolls/buns, soda, chocolate, , , , , , , , , , , , , , , , , , , , , , , , , , , , )</td></tr><tr><td>List(1, other vegetables, , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , )</td></tr><tr><td>List(6, brown bread, soda, fruit/vegetable juice, canned beer, newspapers, shopping bags, , , , , , , , , , , , , , , , , , , , , , , , , , )</td></tr><tr><td>List(4, yogurt, beverages, bottled water, specialty bar, , , , , , , , , , , , , , , , , , , , , , , , , , , , )</td></tr><tr><td>List(7, hamburger meat, ot ...

# %% [markdown]
# d ##### Remove nulls and numbers

# %%
from pyspark.sql.functions import udf
from pyspark.sql.types import StringType
from pyspark.sql.types import ArrayType, StructType

def remove_null(lis):
    final_list = []
    lis = [i for i in lis if i]
    lis = lis[1:len(lis)]
    for i in range(len(lis)):
        final_list.append([lis[i]])
    return final_list

remove_nulls = udf(lambda x: remove_null(x), ArrayType(ArrayType(StringType())))
df2 = df2.withColumn('items', remove_nulls(df2.ValueArray))
display(df2)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ValueArray</th><th>items</th></tr></thead><tbody><tr><td>List(4, citrus fruit, semi-finished bread, margarine, ready soups, , , , , , , , , , , , , , , , , , , , , , , , , , , , )</td><td>List(List(citrus fruit), List(semi-finished bread), List(margarine), List(ready soups))</td></tr><tr><td>List(3, tropical fruit, yogurt, coffee, , , , , , , , , , , , , , , , , , , , , , , , , , , , , )</td><td>List(List(tropical fruit), List(yogurt), List(coffee))</td></tr><tr><td>List(1, whole milk, , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , )</td><td>List(List(whole milk))</td></tr><tr><td>List(4, pip fruit, yogurt, cream cheese, meat spreads, , , , , , , , , , , , , , , , , , , , , , , , , , , , )</td><td>List(List(pip fruit), List(yogurt), List(cream cheese), List(meat spreads))</td></tr><tr><td>List(4, other vegetables, whole milk, condensed milk, long life bakery product, , , , , , , , , , , , , , , , , , , , , , , , , , , , )</td><td>List(List(other vegetables), List(whole milk), List(condensed milk), List(long life bakery product))</td></tr><tr><td>List(5, whole milk, butter, yogurt, rice, abrasive cleaner, , , , , , , , , , , , , , , , , , , , , , , , , , , )</td><td>List(List(whole milk), List(butter), List(yogurt), List(rice), List(abrasive cleaner))</td></tr><tr><td>List(1, rolls/buns, , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , )</td><td>List(List(rolls/buns))</td></tr><tr><td>List(5, other vegetables, UHT-milk, rolls/buns, bottled beer, liquor (appetizer), , , , , , , , , , , , , , , , , , , , , , , , , , , )</td><td>List(List(other vegetables), List(UHT-milk), List(rolls/buns), List(bottled beer), List(liquor (appetizer)))</td></tr><tr><td>List(1, potted plants, , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , )</td><td>List(List(potted plants))</td></tr><tr><td>List(2, whole milk, cereals, , , , , , , , , , , , , , , , , , , , , , , , , , , , , , )</td><td>List(List(whole milk), List(cereals))</td></tr><tr><td>List(5, tropical fruit, other vegetables, white bread, bottled water, chocolate, , , , , , , , , , , , , , , , , , , , , , , , , , , )</td><td>List(List(tropical fruit), List(other vegetables), List(white bread), List(bottled water), List(chocolate))</td></tr><tr><td>List(9, citrus fruit, tropical fruit, whole milk, butter, curd, yogurt, flour, bottled water, dishes, , , , , , , , , , , , , , , , , , , , , , , )</td><td>List(List(citrus fruit), List(tropical fruit), List(whole milk), List(butter), List(curd), List(yogurt), List(flour), List(bottled water), List(dishes))</td></tr><tr><td>List(1, beef, , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , )</td><td>List(List(beef))</td></tr><tr><td>List(3, frankfurter, rolls/buns, soda, , , , , , , , , , , , , , , , , , , , , , , , , , , , , )</td><td>List(List(frankfurter), List(rolls/buns), List(soda))</td></tr><tr><td>List(2, chicken, tropical fruit, , , , , , , , , , , , , , , , , , , , , , , , , , , , , , )</td><td>List(List(chicken), List(tropical fruit))</td></tr><tr><td>List(4, butter, sugar, fruit/vegetable juice, newspapers, , , , , , , , , , , , , , , , , , , , , , , , , , , , )</td><td>List(List(butter), List(sugar), List(fruit/vegetable juice), List(newspapers))</td></tr><tr><td>List(1, fruit/vegetable juice, , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , )</td><td>List(List(fruit/vegetable juice))</td></tr><tr><td>List(1, packaged fruit/vegetables, , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , )</td><td>List(List(packaged fruit/vegetables))</td></tr><tr><td>List(1, chocolate, , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , )</td><td>List(List(chocolate))</td></tr><tr><td>List(1, specialty bar, , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , )</td><td>List(List(specialty bar))</td></tr><tr><td>List(1, other vegetables, , , , , , , , , , , , ,  ...

# %%
df2 = df2.drop('ValueArray')
display(df2)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>items</th></tr></thead><tbody><tr><td>List(List(citrus fruit), List(semi-finished bread), List(margarine), List(ready soups))</td></tr><tr><td>List(List(tropical fruit), List(yogurt), List(coffee))</td></tr><tr><td>List(List(whole milk))</td></tr><tr><td>List(List(pip fruit), List(yogurt), List(cream cheese), List(meat spreads))</td></tr><tr><td>List(List(other vegetables), List(whole milk), List(condensed milk), List(long life bakery product))</td></tr><tr><td>List(List(whole milk), List(butter), List(yogurt), List(rice), List(abrasive cleaner))</td></tr><tr><td>List(List(rolls/buns))</td></tr><tr><td>List(List(other vegetables), List(UHT-milk), List(rolls/buns), List(bottled beer), List(liquor (appetizer)))</td></tr><tr><td>List(List(potted plants))</td></tr><tr><td>List(List(whole milk), List(cereals))</td></tr><tr><td>List(List(tropical fruit), List(other vegetables), List(white bread), List(bottled water), List(chocolate))</td></tr><tr><td>List(List(citrus fruit), List(tropical fruit), List(whole milk), List(butter), List(curd), List(yogurt), List(flour), List(bottled water), List(dishes))</td></tr><tr><td>List(List(beef))</td></tr><tr><td>List(List(frankfurter), List(rolls/buns), List(soda))</td></tr><tr><td>List(List(chicken), List(tropical fruit))</td></tr><tr><td>List(List(butter), List(sugar), List(fruit/vegetable juice), List(newspapers))</td></tr><tr><td>List(List(fruit/vegetable juice))</td></tr><tr><td>List(List(packaged fruit/vegetables))</td></tr><tr><td>List(List(chocolate))</td></tr><tr><td>List(List(specialty bar))</td></tr><tr><td>List(List(other vegetables))</td></tr><tr><td>List(List(butter milk), List(pastry))</td></tr><tr><td>List(List(whole milk))</td></tr><tr><td>List(List(tropical fruit), List(cream cheese), List(processed cheese), List(detergent), List(newspapers))</td></tr><tr><td>List(List(tropical fruit), List(root vegetables), List(other vegetables), List(frozen dessert), List(rolls/buns), List(flour), List(sweet spreads), List(salty snack), List(waffles), List(candy), List(bathroom cleaner))</td></tr><tr><td>List(List(bottled water), List(canned beer))</td></tr><tr><td>List(List(yogurt))</td></tr><tr><td>List(List(sausage), List(rolls/buns), List(soda), List(chocolate))</td></tr><tr><td>List(List(other vegetables))</td></tr><tr><td>List(List(brown bread), List(soda), List(fruit/vegetable juice), List(canned beer), List(newspapers), List(shopping bags))</td></tr><tr><td>List(List(yogurt), List(beverages), List(bottled water), List(specialty bar))</td></tr><tr><td>List(List(hamburger meat), List(other vegetables), List(rolls/buns), List(spices), List(bottled water), List(hygiene articles), List(napkins))</td></tr><tr><td>List(List(root vegetables), List(other vegetables), List(whole milk), List(beverages), List(sugar))</td></tr><tr><td>List(List(pork), List(berries), List(other vegetables), List(whole milk), List(whipped/sour cream), List(artif. sweetener), List(soda), List(abrasive cleaner))</td></tr><tr><td>List(List(beef), List(grapes), List(detergent))</td></tr><tr><td>List(List(pastry), List(soda))</td></tr><tr><td>List(List(fruit/vegetable juice))</td></tr><tr><td>List(List(canned beer))</td></tr><tr><td>List(List(root vegetables), List(other vegetables), List(whole milk), List(dessert))</td></tr><tr><td>List(List(citrus fruit), List(zwieback), List(newspapers))</td></tr><tr><td>List(List(sausage), List(rolls/buns), List(soda), List(canned beer), List(specialty bar), List(shopping bags))</td></tr><tr><td>List(List(tropical fruit), List(root vegetables), List(whole milk), List(yogurt), List(domestic eggs), List(brown bread), List(pastry), List(sugar), List(cereals), List(coffee), List(soda), List(waffles), List(candy))</td></tr><tr><td>List(List(berries), List(yogurt))</td></tr><tr><td>List(List(canned beer))</td></tr><tr><td>List(List(butter milk), List(yogurt), List(cream  ...

# %%
from pyspark.ml.fpm import PrefixSpan



prefixSpan = PrefixSpan(sequenceCol='items', minSupport=0.05, maxPatternLength=32,
                        maxLocalProjDBSize=32000000)

# Find frequent sequential patterns.
result = prefixSpan.findFrequentSequentialPatterns(df2)

# %%
display(result)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sequence</th><th>freq</th></tr></thead><tbody><tr><td>List(List(sausage))</td><td>924</td></tr><tr><td>List(List(bottled beer))</td><td>792</td></tr><tr><td>List(List(pork))</td><td>567</td></tr><tr><td>List(List(shopping bags))</td><td>969</td></tr><tr><td>List(List(yogurt))</td><td>1372</td></tr><tr><td>List(List(frankfurter))</td><td>580</td></tr><tr><td>List(List(soda))</td><td>1715</td></tr><tr><td>List(List(napkins))</td><td>515</td></tr><tr><td>List(List(other vegetables))</td><td>1903</td></tr><tr><td>List(List(fruit/vegetable juice))</td><td>711</td></tr><tr><td>List(List(rolls/buns))</td><td>1809</td></tr><tr><td>List(List(pip fruit))</td><td>744</td></tr><tr><td>List(List(butter))</td><td>545</td></tr><tr><td>List(List(pastry))</td><td>875</td></tr><tr><td>List(List(tropical fruit))</td><td>1032</td></tr><tr><td>List(List(bottled water))</td><td>1087</td></tr><tr><td>List(List(whole milk))</td><td>2513</td></tr><tr><td>List(List(brown bread))</td><td>638</td></tr><tr><td>List(List(whipped/sour cream))</td><td>705</td></tr><tr><td>List(List(domestic eggs))</td><td>624</td></tr><tr><td>List(List(newspapers))</td><td>785</td></tr><tr><td>List(List(citrus fruit))</td><td>814</td></tr><tr><td>List(List(root vegetables))</td><td>1072</td></tr><tr><td>List(List(coffee))</td><td>571</td></tr><tr><td>List(List(margarine))</td><td>576</td></tr><tr><td>List(List(beef))</td><td>516</td></tr><tr><td>List(List(canned beer))</td><td>764</td></tr><tr><td>List(List(curd))</td><td>524</td></tr><tr><td>List(List(other vegetables), List(whole milk))</td><td>736</td></tr><tr><td>List(List(whole milk), List(rolls/buns))</td><td>557</td></tr><tr><td>List(List(whole milk), List(yogurt))</td><td>551</td></tr></tbody></table></div>

# %% [markdown]
# #### Sorted in descending order

# %%
result = result.sort(col("freq"), ascending=False)
display(result)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sequence</th><th>freq</th></tr></thead><tbody><tr><td>List(List(whole milk))</td><td>2513</td></tr><tr><td>List(List(other vegetables))</td><td>1903</td></tr><tr><td>List(List(rolls/buns))</td><td>1809</td></tr><tr><td>List(List(soda))</td><td>1715</td></tr><tr><td>List(List(yogurt))</td><td>1372</td></tr><tr><td>List(List(bottled water))</td><td>1087</td></tr><tr><td>List(List(root vegetables))</td><td>1072</td></tr><tr><td>List(List(tropical fruit))</td><td>1032</td></tr><tr><td>List(List(shopping bags))</td><td>969</td></tr><tr><td>List(List(sausage))</td><td>924</td></tr><tr><td>List(List(pastry))</td><td>875</td></tr><tr><td>List(List(citrus fruit))</td><td>814</td></tr><tr><td>List(List(bottled beer))</td><td>792</td></tr><tr><td>List(List(newspapers))</td><td>785</td></tr><tr><td>List(List(canned beer))</td><td>764</td></tr><tr><td>List(List(pip fruit))</td><td>744</td></tr><tr><td>List(List(other vegetables), List(whole milk))</td><td>736</td></tr><tr><td>List(List(fruit/vegetable juice))</td><td>711</td></tr><tr><td>List(List(whipped/sour cream))</td><td>705</td></tr><tr><td>List(List(brown bread))</td><td>638</td></tr><tr><td>List(List(domestic eggs))</td><td>624</td></tr><tr><td>List(List(frankfurter))</td><td>580</td></tr><tr><td>List(List(margarine))</td><td>576</td></tr><tr><td>List(List(coffee))</td><td>571</td></tr><tr><td>List(List(pork))</td><td>567</td></tr><tr><td>List(List(whole milk), List(rolls/buns))</td><td>557</td></tr><tr><td>List(List(whole milk), List(yogurt))</td><td>551</td></tr><tr><td>List(List(butter))</td><td>545</td></tr><tr><td>List(List(curd))</td><td>524</td></tr><tr><td>List(List(beef))</td><td>516</td></tr><tr><td>List(List(napkins))</td><td>515</td></tr></tbody></table></div>

# %% [markdown]
# d ##### As we can see, out of 9835 transactions, I could only obtained 31 frequent sequential patterns with minimum 5% Support and maxPatternLength equal to 32.
# ##### Out of this, there is only three transaction where two differnt items are bought together, and in those transactions, whole milk was on each of them.

# %% [markdown]
# d ### a. I would say that the results make sense, given that the data is not big enough.
# ### b. There is actually difference regarding the implementation, for example PrefixSpan only accept sequential data type to operate, unlike FP-Growth which accept list data type
# ### c. I can use these two algorithm to make any types of recommendation systems, for example: in movies and merchants.

# %% [markdown]
# #### Apply SON Algorithm
